# %% [markdown]
# # Gaussianization of Galaxy Weak Lensing Signals

# %% [markdown]
# ******

# %% [markdown]
# ## Scatterplots of Gaussianized vs. Ungaussianized Data

# %% [markdown]
# ### Noiseless Maps (/WLconv_z2.00_0001r.fits)

# %% [markdown]
# ![galscatter_allnoiseless](https://github.com/rehg98/weak-lensing/blob/master/weak%20lensing%20plots/Galaxy/galscatter_allnoiseless.PNG?raw=true)

# %% [markdown]
# ******
# ******

# %% [markdown]
# ## Power Spectra

# %% [markdown]
# ### Noiseless Maps (1 Arcminute Smoothing)

# %% [markdown]
# ![galpowermean_allnoiseless](https://github.com/rehg98/weak-lensing/blob/master/weak%20lensing%20plots/Galaxy/galpowermean_allnoiseless.png?raw=true)

# %% [markdown]
# ******
# ******

# %% [markdown]
# ## Comparison Maps

# %% [markdown]
# ### Noiseless Maps (1 Arcminute Smoothing)

# %% [markdown]
# ![galcompare_allnoiseless_diff](https://github.com/rehg98/weak-lensing/blob/master/weak%20lensing%20plots/Galaxy/galcompare_allnoiseless_diff.PNG?raw=true)

# %% [markdown]
# ******
# ******

# %% [markdown]
# ## Correlation Matrices

# %% [markdown]
# ### Noiseless Maps (1 Arcminute Smoothing; Before and After Gaussianization)

# %% [markdown]
# ![galcorrmat_allnoiseless](https://github.com/rehg98/weak-lensing/blob/master/weak%20lensing%20plots/Galaxy/galcorrmat_allnoiseless.png?raw=true)

# %% [markdown]
# ******
# ******

# %% [markdown]
# ## Signal-to-Noise Ratios (in 3.5&deg; x 3.5&deg; area of sky)

# %% [markdown]
# ### Noiseless Maps - smoothing scales (arcminutes) along top, ell maximums along side

# %% [markdown]
# #### Fig. 5: Signal-to-Noise Ratios for Ungaussianized Noiseless Maps

# %% [markdown]
# <table width=70%>
#   <tr>
#     <th></th>
#     <th style="font-size: 15px">1</th>
#     <th style="font-size: 15px">2</th>
#     <th style="font-size: 15px">5</th>
#     <th style="font-size: 15px">10</th>
#   </tr>
#   <tr>
#     <th style="font-size: 15px">2000</th>
#     <td style="font-size: 15px">10.74</td>
#     <td style="font-size: 15px">10.77</td>
#     <td style="font-size: 15px">9.13</td>
#     <td style="font-size: 15px">6.43</td>
#   </tr>
#   <tr>
#     <th style="font-size: 15px">3000</th>
#     <td style="font-size: 15px">12.79</td>
#     <td style="font-size: 15px">12.74</td>
#     <td style="font-size: 15px">9.80</td>
#     <td style="font-size: 15px">6.64</td>
#   </tr>
#   <tr>
#     <th style="font-size: 15px">5000</th>
#     <td style="font-size: 15px">16.85</td>
#     <td style="font-size: 15px">14.08</td>
#     <td style="font-size: 15px">10.02</td>
#     <td style="font-size: 15px">7.01</td>
#   </tr>
# </table>

# %% [markdown]
# #### Fig. 6: Signal-to-Noise Ratios for Gaussianized Noiseless Maps

# %% [markdown]
# <table width=70%>
#   <tr>
#     <th></th>
#     <th style="font-size: 15px">1</th>
#     <th style="font-size: 15px">2</th>
#     <th style="font-size: 15px">5</th>
#     <th style="font-size: 15px">10</th>
#   </tr>
#   <tr>
#     <th style="font-size: 15px">2000</th>
#     <td style="font-size: 15px">11.24</td>
#     <td style="font-size: 15px">10.98</td>
#     <td style="font-size: 15px">9.42</td>
#     <td style="font-size: 15px">6.03</td>
#   </tr>
#   <tr>
#     <th style="font-size: 15px">3000</th>
#     <td style="font-size: 15px">12.89</td>
#     <td style="font-size: 15px">12.52</td>
#     <td style="font-size: 15px">9.84</td>
#     <td style="font-size: 15px">6.05</td>
#   </tr>
#   <tr>
#     <th style="font-size: 15px">5000</th>
#     <td style="font-size: 15px">15.77</td>
#     <td style="font-size: 15px">13.76</td>
#     <td style="font-size: 15px">9.90</td>
#     <td style="font-size: 15px">6.11</td>
#   </tr>
# </table>

# %% [markdown]
# ******
# ******

# %% [markdown]
# ## 1-Point PDFs

# %% [markdown]
# ### Noiseless Maps (1 Arcminute Smoothing)

# %% [markdown]
# ![galpdfs_noiseless](https://github.com/rehg98/weak-lensing/blob/master/weak%20lensing%20plots/Galaxy/galpdfs_noiseless.PNG?raw=true)
